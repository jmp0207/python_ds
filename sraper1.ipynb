# %%
from urllib.request import urlopen
html = urlopen("http://pythonscraping.com/pages/page1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/page1.html")
bsObj = BeautifulSoup(html.read(), "lxml")
print(bsObj.h1)
# Out:
# <h1>An Interesting Title</h1>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://projects.fivethirtyeight.com/soccer-predictions/liga-mx/")
bsObj = BeautifulSoup(html.read(), "lxml")
print(bsObj)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><title>Liga MX Predictions | FiveThirtyEight</title><meta content="u4S1gkGQ7IEq1C4S6i3KdYNnPhtuqfsaSIeP0Qqin68" name="google-site-verification"/><meta content="article" property="og:type"/><meta content="Liga MX Predictions" property="og:title"/><meta content="https://projects.fivethirtyeight.com/soccer-predictions/liga-mx/" property="og:url"/><meta content="FiveThirtyEight's Liga MX predictions" property="og:description"/><meta content="2017-01-19T15:15:00-05:00" property="article:published_time"/><meta content="2019-02-02T00:01:53-05:00" property="article:modified_time"/><meta content="FiveThirtyEight" property="og:site_name"/><meta content="en_US" property="og:locale"/><meta content="https://fivethirtyeight.com/wp-content/uploads/2017/01/promo_4x3_soccerforecast1.jpg" property="og:image"/><meta content="https://fivethirtyeight.com/wp-content/uploads/2017/01/promo_4x3_soccerforecast1.jpg" name="twitter:image:src"/><meta content="summary_large_image" name="twitter:card"/><meta content="https://www.facebook.com/FiveThirtyEight" property="article:publisher"/><meta content="797620670264818" property="fb:app_id"/><meta content="on" name="twitter:widgets:csp"/><meta content="300" name="twitter:maxage"/><meta content="FiveThirtyEight" name="twitter:site"/><meta content="2303751216" name="twitter:site:id"/><meta content="jayboice" name="twitter:creator"/><meta content="961152319" name="twitter:creator:id"/><link href="http://fivethirtyeight.com/osd.xml" rel="search" title="FiveThirtyEight" type="application/opensearchdescription+xml"/><link href="https://wordpress.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/><meta content="FiveThirtyEight" name="application-name"/><meta content="FiveThirtyEight's Liga MX predictions" name="description"/><meta content="https://fivethirtyeight.com/contributors/jay-boice/" property="article:author"/><meta content="Soccer, Club Soccer, Champions League, Premier League, Bundesliga, Ligue 1, Serie A, La Liga, MLS, Liga MX, NWSL, World Football, Football Rankings" name="news_keywords"/><link href="https://fivethirtyeight.com/contributors/jay-boice/" rel="author"/><link href="https://projects.fivethirtyeight.com/shared/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://projects.fivethirtyeight.com/shared/favicon.ico" rel="icon" type="image/x-icon"/><link href="https://projects.fivethirtyeight.com/shared/apple-touch-icon.png" rel="apple-touch-icon"/><link color="#ed713a" href="https://projects.fivethirtyeight.com/shared/safari-pinned-tab.svg" rel="mask-icon"/><link href="https://projects.fivethirtyeight.com/soccer-predictions/liga-mx/" rel="canonical"/><link href="https://projects.fivethirtyeight.com/predicciones-de-futbol/liga-mx/" hreflang="es" rel="alternate"/><link href="https://projects.fivethirtyeight.com/previsoes-de-futebol/liga-mx/" hreflang="pt" rel="alternate"/><script type="text/javascript">var trackingConfig = {
#   postId: "139648",
#   section: "sports",
#   primaryTag: "soccer",
#   pageName: "soccer-predictions",
#   title: "Club Soccer Predictions",
#   author: "Jay Boice, Reuben Fischer-Baum and Julia Wolfe",
#   authorSlug: "boice_jay",
#   fullUrl: "https://projects.fivethirtyeight.com/soccer-predictions/liga-mx/",
#   path: "soccer-predictions/",
#   twitterText: "FiveThirtyEight's Liga MX predictions",
#   locale: "en_US",
#   publishTime: "2017-01-19 15:15"
# }</script><script async="" src="//www.google-analytics.com/analytics.js"></script><script>window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# ga('create', 'UA-60673836-2', 'auto');</script><link href="/soccer-predictions/css/app.css?v=93a8396595c261b5f6b3cadfef42926e" rel="stylesheet"/></head><body><header class="page-header vertical-sports"><div class="header-wrapper"><a class="logo" href="http://fivethirtyeight.com"><img alt="FiveThirtyEight" height="20" src="data:image/svg+xml;base64,..." width="163"/></a><div class="lang-switch mobile" style="display: none"><a class="selected" href="" id="english"><span class="lang">EN</span></a><span class="divider">|</span><a href="" id="spanish"><span class="lang">ES</span></a><span class="divider">|</span><a href="" id="portuguese"><span class="lang">PT</span></a></div><div class="lang-switch desktop" style="display: none"><a class="selected" href="" id="english"><span class="lang">English</span></a><span class="divider">|</span><a href="" id="spanish"><span class="lang">Español</span></a><span class="divider">|</span><a href="" id="portuguese"><span class="lang">Português</span></a></div><div class="social-links"><a class="social share-twitter" href="#" id="twitter-sharer" target="_blank"><div class="icon icon-twitter"></div></a><a class="social share-facebook" href="#" id="facebook-sharer" target="_blank"><div class="icon icon-facebook"></div></a></div></div></header><div id="header-spacer"></div><div class="container"><div id="intro"><div class="timestamp-container"><p class="timestamp">Updated Feb. 2, 2019, at 7:18 PM</p></div><h1>Club Soccer Predictions</h1><h2 class="article-subtitle">Forecasts and Soccer Power Index (SPI) ratings for 36 leagues, updated after each match.</h2><p class="see-also">See also: <a class="see-also-link" href="https://fivethirtyeight.com/methodology/how-our-club-soccer-predictions-work/">How this works</a><a class="see-also-link" href="https://projects.fivethirtyeight.com/global-club-soccer-rankings/">Global club soccer rankings</a></p></div></div><div class="container" id="selection"><nav class="nav"><div class="nav-group"><form class="nav-select" id="js-nav-select"><select class="js-teams select-teams show-desktop" id="leagueselector" name="leagues"><option class="option" value="all-leagues">All leagues</option><optgroup label="Europe"><option class="nav-option" value="champions-league">UEFA Champions League</option><option class="nav-option" value="europa-league">UEFA Europa League</option><option class="nav-option" value="bundesliga-austria">Austria: Bundesliga</option><option class="nav-option" value="first-division-a">Belgium: First Division A</option><option class="nav-option" value="superligaen">Denmark: Superliga</option><option class="nav-option" value="premier-league">England: Premier League</option><option class="nav-option" value="championship">England: Championship</option><option class="nav-option" value="league-one">England: League One</option><option class="nav-option" value="league-two">England: League Two</option><option class="nav-option" value="ligue-1">France: Ligue 1</option><option class="nav-option" value="ligue-2">France: Ligue 2</option><option class="nav-option" value="bundesliga">Germany: Bundesliga</option><option class="nav-option" value="bundesliga-2">Germany: 2. Bundesliga</option><option class="nav-option" value="super-league-greece">Greece: Super League</option><option class="nav-option" value="serie-a">Italy: Serie A</option><option class="nav-option" value="serie-b">Italy: Serie B</option><option class="nav-option" value="eredivisie">Netherlands: Eredivisie</option><option class="nav-option" value="eliteserien">Norway: Eliteserien</option><option class="nav-option" value="primeira-liga">Portugal: Primeira Liga</option><option class="nav-option" value="premier-league-russia">Russia: Premier League</option><option class="nav-option" value="premiership">Scotland: Premiership</option><option class="nav-option" value="la-liga">Spain: La Liga</option><option class="nav-option" value="la-liga-2">Spain: La Liga 2</option><option class="nav-option" value="allsvenska ...
# var allClinches = {"champions-league":{"2016":[{"dt":"2016-08-09","league_id":1818,"team_id":1929,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":160,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":132,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":86,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":382,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":131,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":437,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":243,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":114,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":359,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":83,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":124,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":375,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":111,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":1068,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":174,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":111,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":124,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":132,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":1068,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":375,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":86,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":174,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":83,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":86,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":174,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":111,"typ":"make_round_of_16"},{"dt":"2016-08-09","league_id":1818,"team_id":1068,"typ":"make_round_of_16"},{"dt":"2017-02-12","league_id":1818,"team_id":989,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":148,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":440,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":555,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":570,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":367,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":167,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":1963,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":597,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":909,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":2250,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":13018,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":3852,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":256,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":1895,"typ":"make_round_of_16_elim"},{"dt":"2017-02-12","league_id":1818,"team_id":268,"typ":"make_round_of_16_elim"}],"2017":[{"dt":"2017-10-31","league_id":1818,"team_id":435,"typ":"group_1_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":83,"typ":"group_4_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":360,"typ":"group_4_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":1929,"typ":"group_1_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":160,"typ":"group_4_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":441,"typ":"group_1_elim"},{"dt":"2017-10-31","league_id":1818,"team_id":160,"typ":"group_3_elim"},{"dt":"2017 ...

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup

def getTitle(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        return None
    try:
        bsObj = BeautifulSoup(html.read(),"lxml")
        title = bsObj.body.h1
    except AttributeError as e:
        return None
    return title

title = getTitle("https://projects.fivethirtyeight.com/soccer-predictions/liga-mx/")

if title == None:
    print("Title could not be found")
else:
    print(title)
# Out:
# <h1>Club Soccer Predictions</h1>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html,"html.parser")

for child in bsObj.find("table",{"id":"giftList"}).children:
    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html, "html.parser")

for sibling in bsObj.find("table",{"id":"giftList"}).tr.next_siblings:
    print(sibling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html,"html.parser")
print(bsObj.find("img",{"src":"../img/gifts/img1.jpg"}).parent.previous_sibling.get_text())
# Out:
# $15.00
